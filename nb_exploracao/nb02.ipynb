# %% [markdown]
# # imports and loading data

# %%
# imports
import pandas as pd
import numpy as np
import json
from urllib.request import urlopen

# pandas config
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100
pd.options.display.float_format = '{:,.2f}'.format

# seed reproducibilidade
myseed = 484

# %%
# pegando os dados do github e aprindo o json
data_url = "https://github.com/sthemonica/alura-voz/blob/main/Dados/Telco-Customer-Churn.json?raw=true"
response = urlopen(data_url)
data_json = json.loads(response.read())

# carregando o dataframe
df = pd.json_normalize(data_json, max_level=2, sep='_')

# removendo o prefixo
df.columns = ['_'.join(cols.split('_')[1:]) if len(cols.split('_')) > 1 else cols for cols in df.columns]

# mostrando o cabecalho
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          Yes            No             DSL             No          Yes
# 1          Yes           Yes             DSL             No           No
# 2          Yes            No     Fiber optic             No           No
# 3          Yes            No     Fiber optic             No          Yes
# 4          Yes            No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  Charges_Monthly Charges_Total
# 0              Yes      Mailed check            65.60         593.3
# 1               No      Mailed check            59.90         542.4
# 2              Yes  Electronic check            73.90        280.85
# 3              Yes  Electronic check            98.00       1237.85
# 4              Yes      Mailed check            83.90         267.4

# %%
# classificando colunas em (qualitativos, quantitativos e identificao)
coluna_id = ['customerID']
colunas_quantitativas = ['tenure', 'Charges_Monthly', 'Charges_Total']
colunas_qualitativas = df.drop(colunas_quantitativas + coluna_id, axis=1).columns.tolist()

# dicionario class_var
dict_class_var = { # dicionario classificacao do tipo de variavel
    'QL': 'variavel qualitativa',
    'QT': 'variavel quantitativa',
    'ID': 'variavel de identificacao'
    }

# dicionario informacao das colunas
dict_info_cols = { 
    'customerID': 'número de identificação único de cada cliente',
    'Churn': 'se o cliente deixou ou não a empresa',
    'gender': 'gênero (masculino e feminino)' ,
    'SeniorCitizen': 'informação sobre um cliente ter ou não idade igual ou maior que 65 anos',
    'Partner':  'se o cliente possui ou não um parceiro ou parceira',
    'Dependents': 'se o cliente possui ou não dependentes',
    'tenure':  'meses de contrato do cliente',
    'PhoneService': 'assinatura de serviço telefônico' ,
    'MultipleLines': 'assisnatura de mais de uma linha de telefone' ,
    'InternetService': 'assinatura de um provedor internet' ,
    'OnlineSecurity': 'assinatura adicional de segurança online' ,
    'OnlineBackup': 'assinatura adicional de backup online' ,
    'DeviceProtection': 'assinatura adicional de proteção no dispositivo' ,
    'TechSupport': 'assinatura adicional de suporte técnico, menos tempo de espera',
    'StreamingTV': 'assinatura de TV a cabo',
    'StreamingMovies': 'assinatura de streaming de filmes' ,
    'Contract': 'tipo de contrato',
    'PaperlessBilling': 'se o cliente prefere receber online a fatura',
    'PaymentMethod': 'forma de pagamento',
    'Charges_Monthly': 'total de todos os serviços do cliente por mês',
    'Charges_Total': 'total gasto pelo cliente'
    }

# dicionario traducao coluna
dict_traducao_coluna = {
    'customerID': 'ID', 
    'Churn': 'Churn',
    'gender': 'Genero',
    'SeniorCitizen': 'Senior',
    'Partner': 'Parceiro',
    'Dependents': 'Dependentes',
    'tenure': 'Meses_de_contrato',
    'PhoneService': 'Servico_telefonico',
    'MultipleLines': 'Multiplas_linhas_telefonicas',
    'InternetService': 'Servico_de_internet',
    'OnlineSecurity': 'Seguranca_online',
    'OnlineBackup': 'Backup_online',
    'DeviceProtection': 'Protecao_no_dispositivo',
    'TechSupport': 'Suporte_tecnico',
    'StreamingTV': 'TV_a_cabo',
    'StreamingMovies': 'Streaming_de_filmes',
    'Contract': 'Tipo_de_contrato',
    'PaperlessBilling': 'Fatura_online',
    'PaymentMethod': 'Metodo_de_pagamento',
    'Charges_Monthly': 'Cobrancas_mensais',
    'Charges_Total': 'Cobrancas_total'}

# %%
def df_check(df):
    # criando dataframe para verificacao
    check = pd.DataFrame({'name': df.columns})

    # verificando quantos valores unicos existem em cada  (numero maximo possivel 7267)
    check['nunique'] = df.nunique().values

    # verificando quantidades de nulos
    check['isnull'] = df.isnull().sum().values

    # verificando espacos faltantes
    temp_series1 = df[df.select_dtypes('object').columns].apply(lambda x: x.str.strip().isin(['']).sum()) # colunas str
    temp_series2 = df.select_dtypes(['float', 'integer']).isnull().sum() # colunas numericos
    temp_series = pd.concat([temp_series1, temp_series2])
    temp_series.name = 'blank'
    check = check.merge(temp_series, how='left', left_on='name', right_index=True)

    # verificando data type
    check['dtypes'] = df.dtypes.values

    # vericando quais os valores unicos para colunas com 5 ou menos valores unicos
    check['unique'] = df.apply(lambda x: x.unique() if x.nunique() <= 5 else '-').values

    # classifica (qualitativa, quantitativa, identificacao)
    check['class_var'] = check['name'].replace(colunas_qualitativas, 'QL').replace(
        colunas_quantitativas, 'QT').replace(coluna_id, 'ID' )
    
    # informacoes
    info = check['name'].copy()
    for k in dict_info_cols.keys():
        info.mask(info.str.endswith(k), dict_info_cols[k], inplace=True)
    check['info'] = info

    # traducao
    check['traducao'] = check['name'].map(dict_traducao_coluna)

    # mostrar dataframe
    return check
 
check = df_check(df)
check
# Out:
#                 name  nunique  isnull  blank   dtypes  \
# 0         customerID     7267       0      0   object
# 1              Churn        3       0    224   object
# 2             gender        2       0      0   object
# 3      SeniorCitizen        2       0      0    int64
# 4            Partner        2       0      0   object
# 5         Dependents        2       0      0   object
# 6             tenure       73       0      0    int64
# 7       PhoneService        2       0      0   object
# 8      MultipleLines        3       0      0   object
# 9    InternetService        3       0      0   object
# 10    OnlineSecurity        3       0      0   object
# 11      OnlineBackup        3       0      0   object
# 12  DeviceProtection        3       0      0   object
# 13       TechSupport        3       0      0   object
# 14       StreamingTV        3       0      0   object
# 15   StreamingMovies        3       0      0   object
# 16          Contract        3       0      0   object
# 17  PaperlessBilling        2       0      0   object
# 18     PaymentMethod        4       0      0   object
# 19   Charges_Monthly     1585       0      0  float64
# 20     Charges_Total     6531       0     11   object
#
#                                                                                   unique  \
# 0                                                                                      -
# 1                                                                            [No, Yes, ]
# 2                                                                         [Female, Male]
# 3                                                                                 [0, 1]
# 4                                                                              [Yes, No]
# 5                                                                              [Yes, No]
# 6                                                                                      -
# 7                                                                              [Yes, No]
# 8                                                            [No, Yes, No phone service]
# 9                                                                 [DSL, Fiber optic, No]
# 10                                                        [No, Yes, No internet service]
# 11                                                        [Yes, No, No internet service]
# 12                                                        [No, Yes, No internet service]
# 13                                                        [Yes, No, No internet service]
# 14                                                        [Yes, No, No internet service]
# 15                                                        [No, Yes, No internet service]
# 16                                                  [One year, Month-to-month, Two year]
# 17                                                                             [Yes, No]
# 18  [Mailed check, Electronic check, Credit card (automatic), Bank transfer (automatic)]
# 19                                                                                     -
# 20                                                                                     -
#
#    class_var  \
# 0         ID
# 1         QL
# 2         QL
# 3         QL
# 4         QL
# 5         QL
# 6         QT
# 7         QL
# 8         QL
# 9         QL
# 10        QL
# 11        QL
# 12        QL
# 13        QL
# 14        QL
# 15        QL
# 16        QL
# 17        QL
# 18        QL
# 19        QT
# 20        QT
#
#                                                                        info  \
# 0                             número de identificação único de cada cliente
# 1                                      se o cliente deixou ou não a empresa
# 2                                             gênero (masculino e feminino)
# 3   informação sobre um cliente ter ou não idade igual ou maior que 65 anos
# 4                        se o cliente possui ou não um parceiro ou parceira
# 5                                    se o cliente possui ou não dependentes
# 6                                              meses de contrato do cliente
# 7                                          assinatura de serviço telefônico
# 8                              assisnatura de mais de uma linha de telefone
# 9                                        assinatura de um provedor internet
# 10                                 assinatura adicional de segurança online
# 11                                    assinatura adicional de backup online
# 12                          assinatura adicional de proteção no dispositivo
# 13           assinatura adicional de suporte técnico, menos tempo de espera
# 14                                                  assinatura de TV a cabo
# 15                                        assinatura de streaming de filmes
# 16                                                         tipo de contrato
# 17                             se o cliente prefere receber online a fatura
# 18                                                       forma de pagamento
# 19                            total de todos os serviços do cliente por mês
# 20                                                 total gasto pelo cliente
#
#                         traducao
# 0                             ID
# 1                          Churn
# 2                         Genero
# 3                         Senior
# 4                       Parceiro
# 5                    Dependentes
# 6              Meses_de_contrato
# 7             Servico_telefonico
# 8   Multiplas_linhas_telefonicas
# 9            Servico_de_internet
# 10              Seguranca_online
# 11                 Backup_online
# 12       Protecao_no_dispositivo
# 13               Suporte_tecnico
# 14                     TV_a_cabo
# 15           Streaming_de_filmes
# 16              Tipo_de_contrato
# 17                 Fatura_online
# 18           Metodo_de_pagamento
# 19             Cobrancas_mensais
# 20               Cobrancas_total

# %%
# removendo colunas com Churn igual a ''
df.drop(df[df['Churn'] == ''].index, inplace=True)

# substituir valor faltando numerico por 0
df['Charges_Total'] = pd.to_numeric(df['Charges_Total'], errors='coerce')
df['Charges_Total'].fillna(0, inplace=True)

# %%
check = df_check(df)
check
# Out:
#                 name  nunique  isnull  blank   dtypes  \
# 0         customerID     7043       0      0   object
# 1              Churn        2       0      0   object
# 2             gender        2       0      0   object
# 3      SeniorCitizen        2       0      0    int64
# 4            Partner        2       0      0   object
# 5         Dependents        2       0      0   object
# 6             tenure       73       0      0    int64
# 7       PhoneService        2       0      0   object
# 8      MultipleLines        3       0      0   object
# 9    InternetService        3       0      0   object
# 10    OnlineSecurity        3       0      0   object
# 11      OnlineBackup        3       0      0   object
# 12  DeviceProtection        3       0      0   object
# 13       TechSupport        3       0      0   object
# 14       StreamingTV        3       0      0   object
# 15   StreamingMovies        3       0      0   object
# 16          Contract        3       0      0   object
# 17  PaperlessBilling        2       0      0   object
# 18     PaymentMethod        4       0      0   object
# 19   Charges_Monthly     1585       0      0  float64
# 20     Charges_Total     6531       0      0  float64
#
#                                                                                   unique  \
# 0                                                                                      -
# 1                                                                              [No, Yes]
# 2                                                                         [Female, Male]
# 3                                                                                 [0, 1]
# 4                                                                              [Yes, No]
# 5                                                                              [Yes, No]
# 6                                                                                      -
# 7                                                                              [Yes, No]
# 8                                                            [No, Yes, No phone service]
# 9                                                                 [DSL, Fiber optic, No]
# 10                                                        [No, Yes, No internet service]
# 11                                                        [Yes, No, No internet service]
# 12                                                        [No, Yes, No internet service]
# 13                                                        [Yes, No, No internet service]
# 14                                                        [Yes, No, No internet service]
# 15                                                        [No, Yes, No internet service]
# 16                                                  [One year, Month-to-month, Two year]
# 17                                                                             [Yes, No]
# 18  [Mailed check, Electronic check, Credit card (automatic), Bank transfer (automatic)]
# 19                                                                                     -
# 20                                                                                     -
#
#    class_var  \
# 0         ID
# 1         QL
# 2         QL
# 3         QL
# 4         QL
# 5         QL
# 6         QT
# 7         QL
# 8         QL
# 9         QL
# 10        QL
# 11        QL
# 12        QL
# 13        QL
# 14        QL
# 15        QL
# 16        QL
# 17        QL
# 18        QL
# 19        QT
# 20        QT
#
#                                                                        info  \
# 0                             número de identificação único de cada cliente
# 1                                      se o cliente deixou ou não a empresa
# 2                                             gênero (masculino e feminino)
# 3   informação sobre um cliente ter ou não idade igual ou maior que 65 anos
# 4                        se o cliente possui ou não um parceiro ou parceira
# 5                                    se o cliente possui ou não dependentes
# 6                                              meses de contrato do cliente
# 7                                          assinatura de serviço telefônico
# 8                              assisnatura de mais de uma linha de telefone
# 9                                        assinatura de um provedor internet
# 10                                 assinatura adicional de segurança online
# 11                                    assinatura adicional de backup online
# 12                          assinatura adicional de proteção no dispositivo
# 13           assinatura adicional de suporte técnico, menos tempo de espera
# 14                                                  assinatura de TV a cabo
# 15                                        assinatura de streaming de filmes
# 16                                                         tipo de contrato
# 17                             se o cliente prefere receber online a fatura
# 18                                                       forma de pagamento
# 19                            total de todos os serviços do cliente por mês
# 20                                                 total gasto pelo cliente
#
#                         traducao
# 0                             ID
# 1                          Churn
# 2                         Genero
# 3                         Senior
# 4                       Parceiro
# 5                    Dependentes
# 6              Meses_de_contrato
# 7             Servico_telefonico
# 8   Multiplas_linhas_telefonicas
# 9            Servico_de_internet
# 10              Seguranca_online
# 11                 Backup_online
# 12       Protecao_no_dispositivo
# 13               Suporte_tecnico
# 14                     TV_a_cabo
# 15           Streaming_de_filmes
# 16              Tipo_de_contrato
# 17                 Fatura_online
# 18           Metodo_de_pagamento
# 19             Cobrancas_mensais
# 20               Cobrancas_total

# %%
df.sample(10, random_state=myseed)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 3744  5150-ITWWB    No    Male              1      No         No       3
# 1553  2223-GDSHL    No    Male              0     Yes        Yes      71
# 162   0258-NOKBL    No    Male              0      No         No       3
# 508   0723-DRCLG   Yes  Female              1     Yes         No       1
# 5114  6987-XQSJT   Yes  Female              1      No         No      54
# 2301  3205-MXZRA    No    Male              0      No         No      26
# 5725  7821-DPRQE    No    Male              0     Yes         No      68
# 81    0129-KPTWJ    No    Male              0     Yes         No      72
# 5401  7389-KBFIT    No  Female              0     Yes        Yes       2
# 5654  7721-JXEAW   Yes    Male              0     Yes         No      59
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 3744          Yes               Yes     Fiber optic             No
# 1553          Yes               Yes     Fiber optic            Yes
# 162           Yes                No     Fiber optic             No
# 508           Yes               Yes     Fiber optic             No
# 5114          Yes               Yes     Fiber optic             No
# 2301          Yes                No             DSL             No
# 5725          Yes               Yes     Fiber optic            Yes
# 81            Yes                No     Fiber optic             No
# 5401           No  No phone service             DSL             No
# 5654           No  No phone service             DSL             No
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 3744           No               No          No         Yes             Yes
# 1553          Yes              Yes         Yes         Yes             Yes
# 162           Yes              Yes          No          No             Yes
# 508            No               No          No          No              No
# 5114          Yes               No          No          No              No
# 2301           No               No         Yes         Yes              No
# 5725          Yes               No         Yes         Yes             Yes
# 81             No              Yes          No         Yes             Yes
# 5401          Yes               No          No          No              No
# 5654          Yes               No          No          No             Yes
#
#             Contract PaperlessBilling              PaymentMethod  \
# 3744  Month-to-month              Yes           Electronic check
# 1553        Two year              Yes  Bank transfer (automatic)
# 162   Month-to-month               No           Electronic check
# 508   Month-to-month              Yes           Electronic check
# 5114  Month-to-month              Yes           Electronic check
# 2301        One year               No    Credit card (automatic)
# 5725  Month-to-month              Yes           Electronic check
# 81    Month-to-month              Yes           Electronic check
# 5401  Month-to-month              Yes               Mailed check
# 5654  Month-to-month              Yes  Bank transfer (automatic)
#
#       Charges_Monthly  Charges_Total
# 3744            94.85         335.75
# 1553           116.05       8,297.50
# 162             90.40         268.45
# 508             74.45          74.45
# 5114            79.50       4,370.25
# 2301            59.45       1,507.00
# 5725           107.70       7,320.90
# 81              94.65       6,747.35
# 5401            30.25          63.75
# 5654            41.05       2,452.70

# %%
df_qt = df[colunas_quantitativas].copy()
df_qt.head()
# Out:
#    tenure  Charges_Monthly  Charges_Total
# 0       9            65.60         593.30
# 1       9            59.90         542.40
# 2       4            73.90         280.85
# 3      13            98.00       1,237.85
# 4       3            83.90         267.40

# %%
df_qt['calc_total'] =  df_qt.tenure * df_qt.Charges_Monthly
df_qt['diff_total'] =  df_qt.Charges_Total - df_qt.calc_total

# %%
df_qt['Charge_Monthly_avg'] = df_qt.Charges_Total / df_qt.tenure
df_qt
# Out:
#       tenure  Charges_Monthly  Charges_Total  Charge_Monthly_avg
# 0          9            65.60         593.30               65.92
# 1          9            59.90         542.40               60.27
# 2          4            73.90         280.85               70.21
# 3         13            98.00       1,237.85               95.22
# 4          3            83.90         267.40               89.13
# ...      ...              ...            ...                 ...
# 7262      13            55.15         742.90               57.15
# 7263      22            85.10       1,873.70               85.17
# 7264       2            50.30          92.75               46.38
# 7265      67            67.85       4,627.65               69.07
# 7266      63            59.00       3,707.60               58.85
#
# [7043 rows x 4 columns]
